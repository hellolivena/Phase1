# %%
# import pdb
import os
import time
import datetime
import traceback
import talib
import pandas as pd
from Ayu_lib import CLASS_AYUSH
from dhanhq import dhanhq
import pandas as pd
from datetime import datetime, timedelta, timezone
import ipywidgets as widgets

# %%
ist_offset = timedelta(hours=5, minutes=30)
#dhanlib
client_code="1102634633"
token_id="eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiJ9.eyJpc3MiOiJkaGFuIiwicGFydG5lcklkIjoiIiwiZXhwIjoxNzM2MzY5ODQ1LCJ0b2tlbkNvbnN1bWVyVHlwZSI6IlNFTEYiLCJ3ZWJob29rVXJsIjoiIiwiZGhhbkNsaWVudElkIjoiMTEwMjYzNDYzMyJ9.bJ2qnpR8efbHENikiCJiaMbJH-tBfCKY8__HCFuroCsNk_aj_HWMrBqu65BynCDlKQlbY-47-vYHboZtrBBVHQ"
dhan1=dhanhq(client_code,token_id)
Ayush_obj1=CLASS_AYUSH(client_code,token_id)
master_data=Ayush_obj1.get_instrument_file()
master_data_frame=pd.DataFrame(master_data)
# print(master_data)
# Out:
# -----Logged into Dhan-----
# reading existing file all_instrument 2024-12-25.csv

# %%
# ----INDEX---DATA----
filtered_index_df= master_data_frame[
    (master_data_frame["SEM_TRADING_SYMBOL"] == "NIFTY") &
    (master_data_frame["SEM_EXM_EXCH_ID"] == "NSE") &
    (master_data_frame["SEM_INSTRUMENT_NAME"] == "INDEX") &
    (master_data_frame["SEM_SEGMENT"]=="I")
]

# %%
# index ticker
index_sec_id=13
exchange_segment="IDX_I"
ticker_input={exchange_segment:[int(index_sec_id)]}
tick_data=dhan1.ticker_data(ticker_input)
print(tick_data)
# last_price_int=tick_data['data']['data'][exchange_segment][str(index_sec_id)]['last_price']
# print(last_price_int)
# Out:
# {'status': 'success', 'remarks': '', 'data': {'data': {'IDX_I': {'13': {'last_price': 23727.65}}}, 'status': 'success'}}

# %%
#  FNO ticker
index_sec_id=71355
exchange_segment="NSE_FNO"
ticker_input={exchange_segment:[int(index_sec_id)]}
tick_data=dhan1.ticker_data(ticker_input)
print(tick_data)
# Out:
# {'status': 'success', 'remarks': '', 'data': {'data': {'NSE_FNO': {'71355': {'last_price': 238.4}}}, 'status': 'success'}}

# %%
#index quote data
index_sec_id=13
exchange_segment="IDX_I"
ticker_input={exchange_segment:[int(index_sec_id)]}
tick_data=dhan1.quote_data(ticker_input)
print(tick_data)
# Out:
# {'status': 'success', 'remarks': '', 'data': {'data': {'IDX_I': {'13': {'average_price': 0, 'buy_quantity': 0, 'depth': {'buy': [{'quantity': 0, 'orders': 0, 'price': 0}, {'quantity': 0, 'orders': 0, 'price': 0}, {'quantity': 0, 'orders': 0, 'price': 0}, {'quantity': 0, 'orders': 0, 'price': 0}, {'quantity': 0, 'orders': 0, 'price': 0}], 'sell': [{'quantity': 0, 'orders': 0, 'price': 0}, {'quantity': 0, 'orders': 0, 'price': 0}, {'quantity': 0, 'orders': 0, 'price': 0}, {'quantity': 0, 'orders': 0, 'price': 0}, {'quantity': 0, 'orders': 0, 'price': 0}]}, 'last_price': 23727.65, 'last_quantity': 0, 'last_trade_time': '24/12/2024 15:40:06', 'lower_circuit_limit': 0, 'net_change': 0, 'ohlc': {'open': 23769.1, 'close': 23727.65, 'high': 23867.65, 'low': 23685.15}, 'oi': 0, 'oi_day_high': 0, 'oi_day_low': 0, 'sell_quantity': 0, 'upper_circuit_limit': 0, 'volume': 0}}}, 'status': 'success'}}

# %%
#  FNO quote data
index_sec_id=71355
exchange_segment="NSE_FNO"
ticker_input={exchange_segment:[int(index_sec_id)]}
tick_data=dhan1.quote_data(ticker_input)
print(tick_data)
# Out:
# {'status': 'success', 'remarks': '', 'data': {'data': {'NSE_FNO': {'71355': {'average_price': 210.84, 'buy_quantity': 85775, 'depth': {'buy': [{'quantity': 125, 'orders': 1, 'price': 239}, {'quantity': 50, 'orders': 1, 'price': 238.35}, {'quantity': 550, 'orders': 1, 'price': 238.3}, {'quantity': 125, 'orders': 1, 'price': 237.9}, {'quantity': 250, 'orders': 1, 'price': 237.8}], 'sell': [{'quantity': 325, 'orders': 1, 'price': 239.5}, {'quantity': 250, 'orders': 1, 'price': 239.65}, {'quantity': 2200, 'orders': 7, 'price': 240}, {'quantity': 125, 'orders': 1, 'price': 240.3}, {'quantity': 100, 'orders': 1, 'price': 240.55}]}, 'last_price': 239, 'last_quantity': 25, 'last_trade_time': '24/12/2024 15:29:56', 'lower_circuit_limit': 0.05, 'net_change': -18.25, 'ohlc': {'open': 257.15, 'close': 257.25, 'high': 301.3, 'low': 157.55}, 'oi': 3852625, 'oi_day_high': 5021350, 'oi_day_low': 3852625, 'sell_quantity': 75750, 'upper_circuit_limit': 709.05, 'volume': 31699650}}}, 'status': 'success
# ...

# %%
# index intraday
sec_id=13
exchange_segment="IDX_I"
instrument="INDEX"
fromDate="2024-12-24"
toDate="2024-12-24"
interval=5
hist_data = dhan1.intraday_minute_data(int(sec_id),str(exchange_segment),str(instrument),str(fromDate),str(toDate),int(interval))
hist_data1=pd.DataFrame(hist_data['data']).head(3)
output = widgets.Output()

with output:
    display(hist_data1)
    

output
# Out:
# Output()

# %%
# intraday FNO
sec_id=71355
exchange_segment="NSE_FNO"
instrument="INDEX"
fromDate="2024-12-24"
toDate="2024-12-24"
interval=5
hist_data = dhan1.intraday_minute_data(int(sec_id),str(exchange_segment),str(instrument),str(fromDate),str(toDate),int(interval))
print(hist_data)
# Out:
# {'status': 'failure', 'remarks': {'error_code': 'DH-907', 'error_type': 'Data_Error', 'error_message': 'System is unable to fetch data due to incorrect parameters or no data present'}, 'data': {'errorType': 'Data_Error', 'errorCode': 'DH-907', 'errorMessage': 'System is unable to fetch data due to incorrect parameters or no data present'}}

# %%
# historical daily index
securityId="13"
exchangeSegment="IDX_I"
instrument="INDEX"
expiryCode= 0
fromDate="2024-12-08"
toDate="2024-12-16"
interval=5
hist_data=dhan1.historical_daily_data(securityId,exchangeSegment,instrument,fromDate,toDate,expiryCode)
hist_data1=pd.DataFrame(hist_data['data']).head(3)
output = widgets.Output()

with output:
    display(hist_data1)
    

output
# Out:
# 13 IDX_I INDEX 2024-12-08 2024-12-16 0
# 1
# {"securityId": "13", "exchangeSegment": "IDX_I", "instrument": "INDEX", "expiryCode": 0, "fromDate": "2024-12-08", "toDate": "2024-12-16"}
# <Response [200]>
# Output()

# %%
# historical daily FNO
securityId="71355"
exchangeSegment="NSE_FNO"
instrument="INDEX"
expiryCode= 0
fromDate="2024-12-08"
toDate="2024-12-16"
interval=5
hist_data=dhan1.historical_daily_data(securityId,exchangeSegment,instrument,fromDate,toDate,expiryCode)
hist_data1=pd.DataFrame(hist_data['data'])
print(hist_data1)
# Out:
# 71355 NSE_FNO INDEX 2024-12-08 2024-12-16 0
# 1
# {"securityId": "71355", "exchangeSegment": "NSE_FNO", "instrument": "INDEX", "expiryCode": 0, "fromDate": "2024-12-08", "toDate": "2024-12-16"}
# <Response [200]>
#        open     high       low     close      volume     timestamp
# 0  24763.95  24780.0  24651.70  24694.60   3590100.0  1.733683e+09
# 1  24709.00  24769.0  24595.25  24682.60   4028000.0  1.733769e+09
# 2  24679.90  24798.8  24666.35  24734.90   3922400.0  1.733855e+09
# 3  24721.95  24797.9  24628.00  24648.55   3541625.0  1.733942e+09
# 4  24593.90  24869.0  24231.00  24830.75  11919450.0  1.734028e+09

# %%
# #quote_data
# index_sec_id=71355
# exchange_segment="NSE_FNO"
# ticker_input={exchange_segment:[int(index_sec_id)]}
# # ticker_input={"NSE_FNO":[71355]}
# tick_data2=dhan1.quote_data(ticker_input)
# # print(tick_data2)
# nse_data = pd.DataFrame(tick_data2['data']['data']['NSE_FNO']['71355'])
# nse_data.to_csv('ticker_data.csv',index=False)
# nse_data_depth=pd.DataFrame(tick_data2['data']['data']['NSE_FNO']['71355'])
# nse_data_depth_buy=pd.DataFrame(tick_data2['data']['data']['NSE_FNO']['71355']['depth']['buy'])
# nse_data_depth_sell=pd.DataFrame(tick_data2['data']['data']['NSE_FNO']['71355']['depth']['sell'])


# # print(nse_data_depth)
# # print(nse_data_depth_buy)
# # print(nse_data_depth_sell)

# # Display DataFrame using ipywidgets
# output = widgets.Output()

# with output:
#     # display(nse_data_depth_buy)
#     # display(nse_data_depth_sell)
#     display(nse_data_depth)
    

# output

# %%
# # Fetch historical data
# index_sec_id=(max(filtered_index_df["SEM_SMST_SECURITY_ID"]))
# exchange_segment="IDX_I"
# intsrument="INDEX"
# # fromDate=datetime.now().strftime('%Y-%m-%d')
# # toDate=datetime.now().strftime('%Y-%m-%d')
# fromDate="2024-12-24"
# toDate="2024-12-24"
# interval=1
# hist_data = dhan1.intraday_minute_data(int(index_sec_id),str(exchange_segment),str(intsrument),str(fromDate),str(toDate),int(interval))
# print(hist_data)
# # hist_data1 = hist_data['data']
# # hist_data2 = pd.DataFrame(hist_data1)
# # hist_data2["ist_time"] = hist_data2["timestamp"].apply(
# # lambda x: datetime.fromtimestamp(x, tz=timezone.utc).astimezone(timezone(ist_offset))
# # )
# # print("INDEX INTRADAY")
# # print(hist_data2.tail(2))

# %%
#fno
filtered_strike_df = master_data_frame[
        (master_data_frame["SEM_TRADING_SYMBOL"].str.startswith("NIFTY-")) &
        (master_data_frame["SEM_EXM_EXCH_ID"] == "NSE") &
        (master_data_frame["SEM_INSTRUMENT_NAME"] == "OPTIDX")
    ]


filtered_rows = filtered_strike_df[
        ((filtered_strike_df['SEM_OPTION_TYPE'] == "CE") & (filtered_strike_df['SEM_STRIKE_PRICE'] > last_price_int)) |
        ((filtered_strike_df['SEM_OPTION_TYPE'] == "PE") & (filtered_strike_df['SEM_STRIKE_PRICE'] < last_price_int))
    ]

    # Split into CE and PE rows
ce_row = filtered_rows[filtered_rows['SEM_OPTION_TYPE'] == "CE"].nsmallest(3, 'SEM_STRIKE_PRICE')
pe_row = filtered_rows[filtered_rows['SEM_OPTION_TYPE'] == "PE"].nlargest(3, 'SEM_STRIKE_PRICE')

print("CALL:",last_price_int,ce_row.iloc[0]['SEM_STRIKE_PRICE'],ce_row.iloc[0]['SEM_SMST_SECURITY_ID'])
print("PUT:",last_price_int,pe_row.iloc[0]['SEM_STRIKE_PRICE'],pe_row.iloc[0]['SEM_SMST_SECURITY_ID'])
# Out:
# CALL: 23727.65 23750.0 41685
# PUT: 23727.65 23700.0 41684

# %%
FNO_SEC_ID=ce_row['SEM_SMST_SECURITY_ID'].iloc[0:5].to_list()
fno_sec_string=str(FNO_SEC_ID)


exchange_segment="NSE_FNO"
intsrument="INDEX"
fromDate=datetime.now().strftime('%Y-%m-%d')
toDate=datetime.now().strftime('%Y-%m-%d')
interval=1

print("FNO TICKER")
print(FNO_SEC_ID)
# Out:
# FNO TICKER
# [41685, 46275, 48104]

# %%
# ticker_data_fno
max_buy_map = {"sec": None, "vol": 0}
print("Calls to buy from",FNO_SEC_ID)

# ticker_input_fno={exchange_segment:FNO_SEC_ID}
# tick_data_fno=dhan1.quote_data(ticker_input_fno)
# print(tick_data_fno)
# data_frame=pd.DataFrame(tick_data_fno['data']['data'])



print("FNO intraday")
# Out:
# Calls to buy from [41685, 46275, 48104]
# FNO intraday

# %%
FNO_SEC_ID=[13]
fromDate="2024-12-24"
toDate="2024-12-24"
exchange_segment="IDX_I"
instrument="INDEX"
# #intraday_data_fno
for sec_id in FNO_SEC_ID:
    print(sec_id)
    hist_data = dhan1.intraday_minute_data(str(sec_id),str(exchange_segment),str(intsrument),str(fromDate),str(toDate),(interval))
    print(hist_data)
    hist_data1=hist_data['data']
    hist_data2 = pd.DataFrame(hist_data1)
    hist_data2["ist_time"] = hist_data2["timestamp"].apply(
        lambda x: datetime.fromtimestamp(x, tz=timezone.utc).astimezone(timezone(ist_offset))
    )
    fno_vol=hist_data2['volume'].iloc[-1]
    if max_buy_map['vol']<fno_vol:
        max_buy_map['vol']=fno_vol
        max_buy_map['sec']=sec_id

print("please buy",max_buy_map)
# Out:
# 13
# ...
